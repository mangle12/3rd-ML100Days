# %%
import os
import numpy as np
import pandas as pd
import pathlib as pl

dir_data = './data/'

f_app = os.path.join(dir_data, 'application_train.csv')

#### 用 pd.read_csv 來讀取資料
app_train = pd.read_csv(f_app)

####.head() 前 n行資料
RowHead = app_train.head(10)
#print(RowHead)

#.info() 檔案大小之類的
RowInfo = app_train.info()
#print(RowInfo)

####.tail() 後 n行資料
RowTail = app_train.tail(10)
#print(RowTail)

####.tail() 後 n行資料
RowTail = app_train.tail(10)
#print(RowTail)

####.describe() 各类统计信息(count:總數、mean:平均值、std:標準差)
RowDescribe = app_train.describe()
#print(RowDescribe)

####loc 基於行標籤和列標籤（x_label、y_label）進行索引
####iloc 基於行索引和列索引（index，columns） 都是從 0 開始
top_left_corner_df = app_train.iloc[:5, :5]
#print(top_left_corner_df)

####轉置矩陣（Transpose）
dfT = app_train.T
#print(dfT)

####pandas 基本功能########


##會自動加上字典的 index
s = pd.Series([1,3,6, np.nan, 44, 1])
#print(s)

##日期增加
##pandas.date_range(start=None, end=None, periods=None, freq='D', tz=None, normalize=False, name=None, closed=None, **kwargs)
##start：起日、end：迄日、periods：往後幾天、freq：默認值是'D'，表示以日為單位，'5H'表示每隔5個小時計算一次、tz：時區、
##normalize：默認為False，如果為True的话，那麼在產生時間索引值之前會先把start和end都轉為當日的凌晨0點
##name：默認為None，给返回的时间索引指定一個名字。
dates = pd.date_range('20170101',periods=6)
##print(dates)

##讀取圖片
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('./data/example.jpg')
imgplot = plt.imshow(img)
plt.show()
